# %% [markdown]
# # Micheal Wu's Journal of Error(JOE)

# %% [markdown]
# ### Date: April 12, 2018
# #### Event: Lab 12
# When instruction says
# "Returns a Queue that contains the given items sorted from least to greatest."
# That means don't mutate the original data passed in.
# This means to create a copy of the current data, and manipulate the copy
# ![creates_a_copy.png](attachment:creates_a_copy.png)

# %% [markdown]
# ### Date: April 12, 2018
# #### Event: Lab 12
# Always think about the edge cases, aka when there's 0 input, 1 input, etc
# Attempt to cover those by using the limit such as input <= 1, such that it takes care of both 1 input and 0 input base case.
# ![general_edge_case_handle.png](attachment:general_edge_case_handle.png)
